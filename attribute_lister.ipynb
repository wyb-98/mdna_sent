# %% [markdown]
# Quick program for looking at EDGAR filing attributes

# %%
import pandas as pd
import string as str

# %%
df = pd.read_csv('us_gaap_attributes.csv', index_col=0)

# %%
df.head()
# Out:
#                                            attribute
# 0        AcceleratedShareRepurchaseProgramAdjustment
# 1  AcceleratedShareRepurchasesFinalPricePaidPerShare
# 2  AcceleratedShareRepurchasesSettlementPaymentOr...
# 3  AccountsAndFinancingReceivableAllowanceForCred...
# 4                      AccountsAndNotesReceivableNet

# %%
att_df = df[df.attribute.str.match('Accounts')]

# %%
att_df.head()
# Out:
#                                            attribute
# 3  AccountsAndFinancingReceivableAllowanceForCred...
# 4                      AccountsAndNotesReceivableNet
# 5              AccountsAndOtherReceivablesNetCurrent
# 6          AccountsNotesAndLoansReceivableNetCurrent
# 7                                    AccountsPayable

# %%
att_df.sort_values(by="attribute", key=lambda x: x.str.len())
# Out:
#                                             attribute
# 7                                     AccountsPayable
# 26                              AccountsReceivableNet
# 30                             AccountsReceivableSale
# 15                             AccountsPayableCurrent
# 16                        AccountsPayableOtherCurrent
# 19                        AccountsPayableTradeCurrent
# 27                       AccountsReceivableNetCurrent
# 4                       AccountsAndNotesReceivableNet
# 24                     AccountsReceivableGrossCurrent
# 28                    AccountsReceivableNetNoncurrent
# 29                   AccountsReceivableRelatedParties
# 25                  AccountsReceivableGrossNoncurrent
# 8                AccountsPayableAndAccruedLiabilities
# 18               AccountsPayableRelatedPartiesCurrent
# 5               AccountsAndOtherReceivablesNetCurrent
# 17           AccountsPayableOtherCurrentAndNoncurrent
# ...
